 u'content': u'After the exit polls, it is now time for the final countdown to the 2019 L', 
 u'source': {u'id': u'the-times-of-india', u'name': u'The Times of India'}, 
 u'urlToImage': u'https://static.toiimg.com/thumb/msid-69431083,width-1070,height-580,imgsize-1161232,resizemode-6,overlay-toi_sw,pt-32,y_pad-40/photo.jpg'}, 
 
 {u'description': u'If you are on-the-go, here are the best possible ways to check Lok Sabha Election 2019 results live on any PC or mobile real time.', 
 u'title': u'How to check election results on mobile and PC', 
 u'url': u'https://www.gadgetsnow.com/tech-news/how-to-check-lok-sabha-election-2019-results-in-real-time-on-mobile-and-pc/articleshow/69431084.cms', 
 u'author': u'Gadgets Now Bureau', 
 u'publishedAt': u'2019-05-22T04:41:31Z', 
 u'content': u'After the exit polls, it is now time for the final countdown to ', 
 u'source': {u'id': None, u'name': u'Gadgetsnow.com'}, 
 u'urlToImage': u'https://static.toiimg.com/photo/69431083.cms'}, 
 
 {u'description': u'Cites report claiming ruling party spent \u20b927,000 crore during Lok Sabha election.', 
 u'title': u'Disclose sources of poll funding, Congress asks BJP', 
 u'url': u'https://www.thehindu.com/news/national/disclose-sources-of-poll-funding-congress-asks-bjp/article27689923.ece', 
 u'author': u'Special Correspondent',
 u'publishedAt': u'2019-06-07T16:42:40Z', 
 u'content': u'The Congress on Friday asked the Bharatiya Janata Party (BJP) to disclose the sources ', 
 u'source': {u'id': u'the-hindu', u'name': u'The Hindu'}, 
 u'urlToImage': u'https://www.thehindu.com/news/national/7h8rgw/article27689922.ece/ALTERNATES/LANDSCAPE_615/Singhvi'}]

# %%
df = pd.DataFrame(v)
df
# Out:
#                               author  \
# 0   https://www.facebook.com/bbcnews
# 1   https://www.facebook.com/bbcnews
# 2   https://www.facebook.com/bbcnews
# 3                    Ghazanfar Abbas
# 4   https://www.facebook.com/bbcnews
# 5                               None
# 6                               None
# 7                               None
# 8                 Gadgets Now Bureau
# 9                         Guy Davies
# 10                              None
# 11                    Times Of India
# 12                              None
# 13                The Hindu Net Desk
# 14  https://www.facebook.com/bbcnews
# 15                              None
# 16                Gadgets Now Bureau
# 17             Special Correspondent
#
#                                               content  \
# 0   Between 11 April and 19 May, hundreds of milli...
# 1   Image copyrightReutersImage caption\r\n Many s...
# 2   It's Monday, it's a new week, and while we won...
# ...

# %%
file = 'electionnewcopy.json'
with open(file) as train_file:
    dict_train = json.load(train_file)

# converting json dataset from dictionary to dataframe
train = pd.DataFrame.from_dict(dict_train, orient='index')
train.reset_index(level=0, inplace=True)

# %%
import sys
print(sys.getdefaultencoding())
# Out:
# utf-8

# %%
import json
import pandas as pd
data=[]
f = open('electionnew.txt', 'r')

# %%
import json
import pandas as pd
data=[]
with open('electionnew.txt', 'r') as f:
    print(f)
    data=f.readlines()
df = pd.DataFrame(data)
# Out:
# <_io.TextIOWrapper name='electionnew.txt' mode='r' encoding='UTF-8'>

# %%
json_file = ''.join(data)
json_file
# Out:
# '[{u\'description\': u\'Voters will find out if the BJP or the opposition will form the next government.\',\n u\'title\': u\'Election results 2019 live\', u\'url\':\n u\'https://www.bbc.co.uk/news/world-asia-india-48315659\', \n u\'author\': u\'https://www.facebook.com/bbcnews\', \n u\'publishedAt\': u\'2019-05-23T04:06:32Z\',\n u\'content\': u\'Between 11 April and 19 May, hundreds of millions of Indians voted for members of the Lok Sabha, the lower house of parliament, \n which has 543 elected seats. Live results commenced at 08:00 local time (02:30 GMT).\\r\\nVotes counted on 23 May will show if the alli\\u2026 \n [+769 chars]\', \n u\'source\': {u\'id\': u\'bbc-news\', u\'name\': u\'BBC News\'}, \n u\'urlToImage\': u\'https://ichef.bbci.co.uk/news/1024/branded_news/15CB0/production/_107046298_rahul-modisocialcard.png\'}, \n \n {u\'description\': u\'Prime Minister Narendra Modi has campaigned hard to retain the commanding majority he won in 2014.\', \n u\'title\': u\'India electio
# ...

# %%
final = json_file.split(', \n \n ')

# %%
json_file
# Out:
# '[{u\'description\': u\'Voters will find out if the BJP or the opposition will form the next government.\',\n u\'title\': u\'Election results 2019 live\', u\'url\':\n u\'https://www.bbc.co.uk/news/world-asia-india-48315659\', \n u\'author\': u\'https://www.facebook.com/bbcnews\', \n u\'publishedAt\': u\'2019-05-23T04:06:32Z\',\n u\'content\': u\'Between 11 April and 19 May, hundreds of millions of Indians voted for members of the Lok Sabha, the lower house of parliament, \n which has 543 elected seats. Live results commenced at 08:00 local time (02:30 GMT).\\r\\nVotes counted on 23 May will show if the alli\\u2026 \n [+769 chars]\', \n u\'source\': {u\'id\': u\'bbc-news\', u\'name\': u\'BBC News\'}, \n u\'urlToImage\': u\'https://ichef.bbci.co.uk/news/1024/branded_news/15CB0/production/_107046298_rahul-modisocialcard.png\'}, \n \n {u\'description\': u\'Prime Minister Narendra Modi has campaigned hard to retain the commanding majority he won in 2014.\', \n u\'title\': u\'India electio
# ...

# %%
final[0]
# Out:
# "[{u'description': u'Voters will find out if the BJP or the opposition will form the next government.',\n u'title': u'Election results 2019 live', u'url':\n u'https://www.bbc.co.uk/news/world-asia-india-48315659', \n u'author': u'https://www.facebook.com/bbcnews', \n u'publishedAt': u'2019-05-23T04:06:32Z',\n u'content': u'Between 11 April and 19 May, hundreds of millions of Indians voted for members of the Lok Sabha, the lower house of parliament, \n which has 543 elected seats. Live results commenced at 08:00 local time (02:30 GMT).\\r\\nVotes counted on 23 May will show if the alli\\u2026 \n [+769 chars]', \n u'source': {u'id': u'bbc-news', u'name': u'BBC News'}, \n u'urlToImage': u'https://ichef.bbci.co.uk/news/1024/branded_news/15CB0/production/_107046298_rahul-modisocialcard.png'}"

# %%
df = pd.DataFrame(json_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-cf8f5cd4c6d3> in <module>
# ----> 1 df = pd.DataFrame(json_file)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
df
# Out:
#                                                     0
# 0   {u'description': u'Voters will find out if the...
# 1   {u'description': u'Prime Minister Narendra Mod...
# 2   {u'description': u'Europe heads to the polls a...
# 3   {u'description': u'Sheila Dikshit vs Manoj Tiw...
# 4   {u'description': u"Analysis of the results of ...
# 5   {u'description': u'Five of the seven-phase Lok...
# 6   {u'description': u'The Lok Sabha scoreline set...
# 7   {u'description': u'The focus has shifted to th...
# 8   {u'description': u'The focus has shifted to th...
# 9   {u'description': u'The Election Commission of ...
# 10  {u'description': u'Get breaking national and w...
# 11  {u'description': u"A supporter of India's ruli...
# 12  {u'description': u'Lok Sabha Elections 2019 Ne...
# 13  {u'description': u"Lok Sabha Elections 2019 Ne...
# 14  {u'description': u'Stay updated with Times of ...
# 15  {u'description': u'The Biju Janata Ddal looks ...
# ...
